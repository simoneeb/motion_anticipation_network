# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import interp1d
from scipy.ndimage import gaussian_filter
import pickle
from scipy.signal import convolve

# %%
speeds = [0.27,0.81,1.62,3.24,0.1,0.2,0.4,0.5,0.6,0.7,0.8,0.9,1.0]
speeds = [0.81]

# %% [markdown]
# # load RAM  reversal simulations fixed

# %%
#reversal
data = []
cell = 150

for s in speeds: 
    print(s)
    fp = f'/user/sebert/home/Documents/Simulations/motion/anticipation_1D/Reciporcal/Reciporcal_mono_linear_plastic_opt/noGCGainControl/only_one_plastic/betaB/betaB_0.0/reversing_{s}'
    with open(f'{fp}/out', 'rb') as handle:
        out = pickle.load(handle)    
        
    with open(f'{fp}/params', 'rb') as handle:
        paramsi = pickle.load(handle)

    duration = paramsi['duration']
    dt = paramsi['dt']
    #time = (np.arange(0,duration,dt)- params['tps_rf_GC_mid'][50])*1000
    time = np.arange(0,duration,dt) - 1#+45
    data.append([time,out['RG'][:]])

    if s == 0.81:
        outd = out
# Out:
# 0.81

# %%
#smooth
datas = []
cell = 150

for s in speeds: 
    print(s)
    fp = f'/user/sebert/home/Documents/Simulations/motion/anticipation_1D/Reciporcal/Reciporcal_mono_linear_plastic_opt/noGCGainControl/only_one_plastic/betaB/betaB_0.0/smooth_{s}'
    with open(f'{fp}/out', 'rb') as handle:
        out = pickle.load(handle)    
        
    with open(f'{fp}/params', 'rb') as handle:
        paramsi = pickle.load(handle)

    duration = paramsi['duration']
    dt = paramsi['dt']
    #time = (np.arange(0,duration,dt)- params['tps_rf_GC_mid'][50])*1000
    time = np.arange(0,duration,dt) - (paramsi['spacing']*cell)/paramsi['speed']#+45
    datas.append([time,out['RG'][:]])

    if s == 0.81:
        outds = out
# Out:
# 0.81

# %% [markdown]
# # RAM plastic A

# %%
dataA = []
cell = 150

for s in speeds: 
    print(s)
    fp = f'/user/sebert/home/Documents/Simulations/motion/anticipation_1D/Reciporcal/Reciporcal_mono_linear_plastic_opt/noGCGainControl/betaB/betaB_0.0/reversing_{s}'
    with open(f'{fp}/out', 'rb') as handle:
        out = pickle.load(handle)    
        
    with open(f'{fp}/params', 'rb') as handle:
        paramsi = pickle.load(handle)

    duration = paramsi['duration']
    dt = paramsi['dt']
    #time = (np.arange(0,duration,dt)- params['tps_rf_GC_mid'][50])*1000
    time = np.arange(0,duration,dt) - 1#+45
    dataA.append([time,out['RG'][:]])

    if s == 0.81:
        outdA = out
# Out:
# 0.81

# %%
dataAs = []
cell = 150

for s in speeds: 
    print(s)
    fp = f'/user/sebert/home/Documents/Simulations/motion/anticipation_1D/Reciporcal/Reciporcal_mono_linear_plastic_opt/noGCGainControl/betaB/betaB_0.0/smooth_{s}'
    with open(f'{fp}/out', 'rb') as handle:
        out = pickle.load(handle)    
        
    with open(f'{fp}/params', 'rb') as handle:
        paramsi = pickle.load(handle)

    duration = paramsi['duration']
    dt = paramsi['dt']
    #time = (np.arange(0,duration,dt)- params['tps_rf_GC_mid'][50])*1000
    time = np.arange(0,duration,dt) - (paramsi['spacing']*cell)/paramsi['speed']
    dataAs.append([time,out['RG'][:]])

    if s == 0.81:
        outdAs = out
# Out:
# 0.81

# %% [markdown]
# # RAM plastic B

# %%
dataB = []
cell = 150

for s in speeds: 
    print(s)
    fp = f'/user/sebert/home/Documents/Simulations/motion/anticipation_1D/Reciporcal/Reciporcal_mono_linear_plastic_opt/noGCGainControl/betaA/betaA_0.0/reversing_{s}'
    with open(f'{fp}/out', 'rb') as handle:
        out = pickle.load(handle)    
        
    with open(f'{fp}/params', 'rb') as handle:
        paramsi = pickle.load(handle)

    duration = paramsi['duration']
    dt = paramsi['dt']
    #time = (np.arange(0,duration,dt)- params['tps_rf_GC_mid'][50])*1000
    time = np.arange(0,duration,dt) - 1#+45
    dataB.append([time,out['RG'][:]])

    if s == 0.81:
        outdB = out
# Out:
# 0.81

# %%
dataBs = []
cell = 150

for s in speeds: 
    print(s)
    fp = f'/user/sebert/home/Documents/Simulations/motion/anticipation_1D/Reciporcal/Reciporcal_mono_linear_plastic_opt/noGCGainControl/betaA/betaA_0.0/smooth_{s}'
    with open(f'{fp}/out', 'rb') as handle:
        out = pickle.load(handle)    
        
    with open(f'{fp}/params', 'rb') as handle:
        paramsi = pickle.load(handle)

    duration = paramsi['duration']
    dt = paramsi['dt']
    #time = (np.arange(0,duration,dt)- params['tps_rf_GC_mid'][50])*1000
    time = np.arange(0,duration,dt) - (paramsi['spacing']*cell)/paramsi['speed']
    dataBs.append([time,out['RG'][:]])

    if s == 0.81:
        outdBs = out
# Out:
# 0.81

# %% [markdown]
# # RAM plastic both

# %%
dataAB = []
cell = 150

for s in speeds: 
    print(s)
    fp = f'/user/sebert/home/Documents/Simulations/motion/anticipation_1D/Reciporcal/Reciporcal_mono_linear_plastic_opt/noGCGainControl/betaA/betaA_0.03/reversing_{s}'
    with open(f'{fp}/out', 'rb') as handle:
        out = pickle.load(handle)    
        
    with open(f'{fp}/params', 'rb') as handle:
        paramsi = pickle.load(handle)

    duration = paramsi['duration']
    dt = paramsi['dt']
    #time = (np.arange(0,duration,dt)- params['tps_rf_GC_mid'][50])*1000
    time = np.arange(0,duration,dt) - 1#+45
    dataAB.append([time,out['RG'][:]])

    if s == 0.81:
        outdAB = out
# Out:
# 0.81

# %%
dataABs = []
cell = 150

for s in speeds: 
    print(s)
    fp = f'/user/sebert/home/Documents/Simulations/motion/anticipation_1D/Reciporcal/Reciporcal_mono_linear_plastic_opt/noGCGainControl/betaA/betaA_0.03/smooth_{s}'
    with open(f'{fp}/out', 'rb') as handle:
        out = pickle.load(handle)    
        
    with open(f'{fp}/params', 'rb') as handle:
        paramsi = pickle.load(handle)

    duration = paramsi['duration']
    dt = paramsi['dt']
    #time = (np.arange(0,duration,dt)- params['tps_rf_GC_mid'][50])*1000
    time = np.arange(0,duration,dt) - (paramsi['spacing']*cell)/paramsi['speed']
    dataABs.append([time,out['RG'][:]])

    if s == 0.81:
        outdABs = out
# Out:
# 0.81

# %% [markdown]
# # plot onset response of fixed RAM at different stages

# %%
rev_pos = 150
dis = 10

# %%
lw = 4
c1 = 'green'
c2 = 'red'
c22 = 'grey'
c3 = 'blue'
c4 = 'purple'


fig,ax = plt.subplots(5,4,  figsize = (12,12), sharex = 'col', sharey = 'row')

ax[0,0].set_title('RAM fixed', loc = 'left')
ax[0,1].set_title('RAM plastic A', loc = 'left')
ax[0,2].set_title('RAM plastic B', loc = 'left')
ax[0,3].set_title('RAM plastic both', loc = 'left')



ax[0,0].set_ylabel('$input$')
ax[0,0].plot(datas[0][0],outds['inp'][:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[0,0].plot(data[0][0],outd['inp'][rev_pos+i*dis,:], color = c1, linewidth = lw, label = f'{i*(dis*5)} mum')
#ax[0,0].plot(data[0][0],outd['F'][:], color = c1, linewidth = lw)

ax[1,0].set_ylabel('$V_{B}(t)$')
ax[1,0].plot(datas[0][0],outds['VB'][50,:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[1,0].plot(data[0][0],outd['VB'][rev_pos+i*dis,:], color = c1, linewidth = lw)# for c in range(50):
#     ax[1,0].plot(data[0][0],outd['VB'][c,:], color = 'k', linewidth = 1)

ax[2,0].set_ylabel('$R_{B}(t)$')
ax[2,0].plot(datas[0][0], outds['RB'][50,:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[2,0].plot(data[0][0],outd['RB'][rev_pos+i*dis,:], color = c1, linewidth = lw)# for c in range(50):

ax[3,0].set_ylabel('$V_{G}(t)$')
ax[3,0].plot(datas[0][0], outds['VG'][:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[3,0].plot(data[0][0],outd['VG'][rev_pos+i*dis,:], color = c1, linewidth = lw)# for c in range(50):


ax[4,0].set_ylabel('$R_{G}(t)$')
ax[4,0].plot(datas[0][0], outds['RG'][:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[4,0].plot(data[0][0],outd['RG'][rev_pos+i*dis,:], color = c1, linewidth = lw)# for c in range(50):



ax[0,1].plot(dataAs[0][0],outdAs['inp'][:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[0,1].plot(dataA[0][0],outdA['inp'][rev_pos+i*dis,:], color = c2, linewidth = lw, label = f'{i*(dis*5)} mum')

ax[1,1].plot(dataAs[0][0],outdAs['VB'][50,:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[1,1].plot(dataA[0][0],outdA['VB'][rev_pos+i*dis,:], color = c2, linewidth = lw)

ax[2,1].plot(dataAs[0][0], outdAs['RB'][50,:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[2,1].plot(dataA[0][0],outdA['RB'][rev_pos+i*dis,:], color = c2, linewidth = lw)


ax[3,1].plot(dataAs[0][0], outdAs['VG'][:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[3,1].plot(dataA[0][0],outdA['VG'][rev_pos+i*dis,:], color = c2, linewidth = lw)


ax[4,1].plot(dataAs[0][0], outdAs['RG'][:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[4,1].plot(dataA[0][0],outdA['RG'][rev_pos+i*dis,:], color = c2, linewidth = lw)




ax[0,2].plot(dataBs[0][0],outdBs['inp'][:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[0,2].plot(dataB[0][0],outdB['inp'][rev_pos+i*dis,:], color = c3, linewidth = lw, label = f'{i*(dis*5)} mum')

    
ax[1,2].plot(dataBs[0][0],outdBs['VB'][50,:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[1,2].plot(dataB[0][0],outdB['VB'][rev_pos+i*dis,:], color = c3, linewidth = lw)


ax[2,2].plot(dataBs[0][0], outdBs['RB'][50,:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[2,2].plot(dataB[0][0],outdB['RB'][rev_pos+i*dis,:], color = c3, linewidth = lw)

ax[3,2].plot(dataBs[0][0], outdBs['VG'][:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[3,2].plot(dataB[0][0],outdB['VG'][rev_pos+i*dis,:], color = c3, linewidth = lw)

ax[4,2].plot(dataBs[0][0], outdBs['RG'][:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[4,2].plot(dataB[0][0],outdB['RG'][rev_pos+i*dis,:], color = c3, linewidth = lw)



ax[0,3].plot(dataABs[0][0],outdABs['inp'][:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[0,3].plot(dataAB[0][0],outdAB['inp'][rev_pos+i*dis,:], color = c4, linewidth = lw, label = f'{i*(dis*5)} mum')

ax[1,3].plot(dataABs[0][0],outdABs['VB'][50,:], color = c3, linewidth = lw)
for i in range(-3,3):
    ax[1,3].plot(dataAB[0][0],outdAB['VB'][rev_pos+i*dis,:], color = c4, linewidth = lw)

ax[2,3].plot(dataABs[0][0], outdABs['RB'][50,:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[2,3].plot(dataAB[0][0],outdAB['RB'][rev_pos+i*dis,:], color = c4, linewidth = lw)

ax[3,3].plot(dataABs[0][0], outdABs['VG'][:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[3,3].plot(dataAB[0][0],outdAB['VG'][rev_pos+i*dis,:], color = c4, linewidth = lw)

ax[4,3].plot(dataABs[0][0], outdABs['RG'][:], color = c22, linewidth = lw)
for i in range(-3,3):
    ax[4,3].plot(dataAB[0][0],outdAB['RG'][rev_pos+i*dis,:], color = c4, linewidth = lw)



ax[0,1].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[1,1].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[2,1].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[3,1].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[4,1].axvline(0,linestyle = ':', color = 'k', linewidth =2 )


ax[0,0].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[1,0].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[2,0].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[3,0].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[4,0].axvline(0,linestyle = ':', color = 'k', linewidth =2 )

ax[0,2].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[1,2].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[2,2].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[3,2].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[4,2].axvline(0,linestyle = ':', color = 'k', linewidth =2 )


ax[0,3].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[1,3].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[2,3].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[3,3].axvline(0,linestyle = ':', color = 'k', linewidth =2 )
ax[4,3].axvline(0,linestyle = ':', color = 'k', linewidth =2 )


ax[-1,0].set_xlabel ('time [s]')
ax[-1,1].set_xlabel ('time [s]')
ax[-1,2].set_xlabel ('time [s]')
ax[-1,3].set_xlabel ('time [s]')
ax[-1,0].set_xlim(-0,1)
ax[-1,1].set_xlim(-0,1)
ax[-1,2].set_xlim(-0,1)
ax[-1,3].set_xlim(-0,1)
# Out:
# (0.0, 1.0)
