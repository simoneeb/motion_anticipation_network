# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import sys

sys.path.append("../lib") # add code library to paths

# add lib to path 
from visualize import *

# %%
netname = 'recurrent_nn'
stimname = 'gStep'
sigB = np.load(f'../output/{netname}/BC_grid_{stimname}.npy')
sigA = np.load(f'../output/{netname}/AC_grid_{stimname}.npy')
sigG = np.load(f'../output/{netname}/GC_grid_{stimname}.npy')
stim = np.load(f'../output/{netname}/stim_grid_{stimname}.npy')

output = [stim,sigB,sigA,sigG]
        
with open(f'../output/{netname}/params.pkl', 'rb') as f:
    params = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 netname = 'recurrent_nn'
#       2 stimname = 'gStep'
# ----> 3 sigB = np.load(f'../output/{netname}/BC_grid_{stimname}.npy')
#       4 sigA = np.load(f'../output/{netname}/AC_grid_{stimname}.npy')
#       5 sigG = np.load(f'../output/{netname}/GC_grid_{stimname}.npy')
#
# File /.pyenv/versions/3.11.5/lib/python3.11/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output/recurrent_nn/BC_grid_gStep.npy'

# %%
fig = plot_grid(output,params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 fig = plot_grid(output,params)
#
# NameError: name 'output' is not defined

# %%
fig = plot_timetrace(output, params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fig = plot_timetrace(output, params)
#
# NameError: name 'output' is not defined

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# load df
stimname = 'gStep'
df = pd.read_csv(f'../output/{netname}/{stimname}/grid_steadystate.csv')

# %%
fig,ax = plt.subplots(1)

# plot heatmap for beta
cbar_ax = fig.add_axes([.91, .3, .03, .4])
heatmap = df.pivot_table(index = 'wBA',columns = 'tauA',values = 'VB*', aggfunc = 'mean')
coo = sns.heatmap(heatmap, cmap = 'viridis', ax = ax,  cbar_ax=cbar_ax,cbar_kws={'label': r'$V_{B}*$ [mV]'})
ax.tick_params(left=False, bottom=False)
